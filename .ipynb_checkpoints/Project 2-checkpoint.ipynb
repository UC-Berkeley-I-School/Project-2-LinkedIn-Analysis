# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = '/Users/rickypang/Desktop/Project-2-Linkedin-Analysis/data/job_postings.csv'
df=pd.read_csv(filepath)

#convert date columns to date time
df['listed_time'] = pd.to_datetime(df['listed_time'], unit='ms')
df['original_listed_time'] = pd.to_datetime(df['original_listed_time'], unit='ms')

#convert company ID to an int, convert NaN to NaN
df['company_id'] = pd.to_numeric(df['company_id'], errors='coerce').astype('Int64')

#Pre-process and convert NaNs in company ID to -1
df['company_id'] = df['company_id'].fillna(-1)

#display df
df
# Out:
#            job_id  company_id  \
# 0      3757940104      553718
# 1      3757940025     2192142
# 2      3757938019      474443
# 3      3757938018    18213359
# 4      3757937095      437225
# ...           ...         ...
# 33241   133114754    77766802
# 33242   108965123          -1
# 33243   102339515    52132271
# 33244    85008768          -1
# 33245     3958427      630152
#
#                                                    title  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# 33243                                    Franchise Owner
# 33244                           Licensed Insurance Agent
# 33245                                   Stylist/ Clorist
#
#                                              description  max_salary  \
# 0      Overview\n\nHearingLife is a national hearing ...         NaN
# 1      Metalcraft of Mayville\nMetalcraft of Mayville...         NaN
# 2      \nThe TSUBAKI name is synonymous with excellen...         NaN
# 3      descriptionTitle\n\n Looking for a great oppor...         NaN
# 4      Job Summary\nAt iHerb, we are on a mission to ...    275834.0
# ...                                                  ...         ...
# 33241  Are you a dynamic and creative marketing profe...         NaN
# 33242  A fast-fashion wholesaler, is looking for a fu...         NaN
# 33243  DuctVentz is a dryer and A/C – heat vent clean...         NaN
# 33244  While many industries were hurt by the last fe...     52000.0
# 33245  Karen Marie is looking for an awesome experien...     80000.0
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 0         5250.00         NaN    MONTHLY           Full-time
# 1             NaN         NaN        NaN           Full-time
# 2             NaN         NaN        NaN           Full-time
# 3           22.27         NaN     HOURLY           Full-time
# 4             NaN    205956.0     YEARLY           Full-time
# ...           ...         ...        ...                 ...
# 33241         NaN         NaN        NaN           Full-time
# 33242         NaN         NaN        NaN           Full-time
# 33243         NaN         NaN        NaN           Full-time
# 33244         NaN     45760.0     YEARLY           Full-time
# 33245         NaN     35000.0     YEARLY           Full-time
#
#                 location  ...  closed_time formatted_experience_level  \
# 0       Little River, SC  ...          NaN                Entry level
# 1         Beaver Dam, WI  ...          NaN                        NaN
# 2           Bessemer, AL  ...          NaN                        NaN
# 3        Aliso Viejo, CA  ...          NaN                Entry level
# 4          United States  ...          NaN           Mid-Senior level
# ...                  ...  ...          ...                        ...
# 33241  Santa Clarita, CA  ...          NaN                        NaN
# 33242       New York, NY  ...          NaN                        NaN
# 33243     Greater Boston  ...          NaN                        NaN
# 33244          Chico, CA  ...          NaN                        NaN
# 33245        Chicago, IL  ...          NaN                        NaN
#
#                                              skills_desc         listed_time  \
# 0                                                    NaN 2023-11-04 09:26:40
# 1                                                    NaN 2023-11-04 06:40:00
# 2      Bachelor's Degree in Mechanical Engineering pr... 2023-11-04 06:40:00
# 3                                                    NaN 2023-11-04 06:40:00
# 4                                                    NaN 2023-11-04 09:26:40
# ...                                                  ...                 ...
# 33241                                                NaN 2023-08-23 22:33:20
# 33242                                                NaN 2023-11-03 19:33:20
# 33243                                                NaN 2023-11-03 22:20:00
# 33244                                                NaN 2023-08-23 00:20:00
# 33245  Must be a seasoned stylist with an existing bo... 2023-11-03 22:20:00
#
#                  posting_domain sponsored  work_type  currency  \
# 0      careers-demant.icims.com         0  FULL_TIME       USD
# 1           www.click2apply.net         0  FULL_TIME       NaN
# 2           www.click2apply.net         0  FULL_TIME       NaN
# 3               jobs.apploi.com         0  FULL_TIME       USD
# 4             careers.iherb.com         0  FULL_TIME       USD
# ...                         ...       ...        ...       ...
# 33241                       NaN         0  FULL_TIME       NaN
# 33242                       NaN         0  FULL_TIME       NaN
# 33243                       NaN         0  FULL_TIME       NaN
# 33244                       NaN         1  FULL_TIME       USD
# 33245                       NaN         0  FULL_TIME       USD
#
#        compensation_type     scraped
# 0            BASE_SALARY  1699138101
# 1                    NaN  1699085420
# 2                    NaN  1699085644
# 3            BASE_SALARY  1699087461
# 4            BASE_SALARY  1699085346
# ...                  ...         ...
# 33241                NaN           1
# 33242                NaN  1699044401
# 33243                NaN  1699063495
# 33244        BASE_SALARY           1
# 33245        BASE_SALARY  1699057868
#
# [33246 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# job_id                            0
# company_id                        0
# title                             0
# description                       1
# max_salary                    22135
# med_salary                    31005
# min_salary                    22135
# pay_period                    19894
# formatted_work_type               0
# location                          0
# applies                       17008
# original_listed_time              0
# remote_allowed                28444
# views                          7360
# job_posting_url                   0
# application_url               12250
# application_type                  0
# expiry                            0
# closed_time                   32074
# formatted_experience_level     9181
# skills_desc                   32909
# listed_time                       0
# posting_domain                13558
# sponsored                         0
# work_type                         0
# currency                      19894
# compensation_type             19894
# scraped                           0
# dtype: int64

# %%
c=df.corr()
mask=np.ones_like(c, dtype=np.bool)
mask=np.triu(mask)
sns.heatmap(c, annot=True, fmt=".2f", annot_kws={"size": 10},mask=mask)
# Out:
# /var/folders/5n/f53vsb0n34q3sstd084mv7g80000gn/T/ipykernel_39474/3928678452.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=df.corr()
# /var/folders/5n/f53vsb0n34q3sstd084mv7g80000gn/T/ipykernel_39474/3928678452.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.ones_like(c, dtype=np.bool)
# <Axes: >

# %%
filepathforcompany = '/Users/rickypang/Desktop/Project-2-Linkedin-Analysis/data/company_details/companies.csv'
df2 = pd.read_csv(filepathforcompany)
df2
# Out:
#        company_id                                    name  \
# 0            1009                                     IBM
# 1            1016                           GE HealthCare
# 2            1021                                GE Power
# 3            1025              Hewlett Packard Enterprise
# 4            1028                                  Oracle
# ...           ...                                     ...
# 11356  3700144594                                  BYREDO
# 11357  3700144710  Pros2Plan, a division of Spinnaker SCA
# 11358  3700147810                       Ascendo Resources
# 11359  3700150295                          The Crox Group
# 11360  3700152513                       Sidley Austin LLP
#
#                                              description  company_size  \
# 0      At IBM, we do more than work. We create. We cr...           7.0
# 1      Every day millions of people feel the impact o...           7.0
# 2      GE Power, part of GE Vernova, is a world energ...           7.0
# 3      Official LinkedIn of Hewlett Packard Enterpris...           7.0
# 4      We’re a cloud technology company that provides...           7.0
# ...                                                  ...           ...
# 11356  "Beauty can be many things to many people. Our...           3.0
# 11357  Pros2Plan, a  division of Spinnaker Services L...           2.0
# 11358  Ascendo Resources is a certified minority owne...           3.0
# 11359  The Crox Group, Head Quartered in Chicago, wit...           2.0
# 11360  Sidley is an elite global law firm with nearly...           5.0
#
#           state country              city zip_code  \
# 0            NY      US  Armonk, New York    10504
# 1             0      US           Chicago        0
# 2            NY      US       Schenectady    12345
# 3         Texas      US           Houston    77389
# 4         Texas      US            Austin    78741
# ...         ...     ...               ...      ...
# 11356         0       0                 0        0
# 11357        CO      US           Boulder    80303
# 11358        FL      US      Coral Gables    33134
# 11359  Illinois      US       Lincolnwood    60712
# 11360  Illinois      US           Chicago    60603
#
#                                      address  \
# 0      International Business Machines Corp.
# 1                                          -
# 2                               1 River Road
# 3                1701 E Mossy Oaks Rd Spring
# 4                            2300 Oracle Way
# ...                                      ...
# 11356                                      0
# 11357                                      0
# 11358                       2 Alhambra Plaza
# 11359                     6818 N Lincoln Ave
# 11360                     One South Dearborn
#
#                                                      url
# 0                   https://www.linkedin.com/company/ibm
# 1          https://www.linkedin.com/company/gehealthcare
# 2               https://www.linkedin.com/company/gepower
# 3      https://www.linkedin.com/company/hewlett-packa...
# 4                https://www.linkedin.com/company/oracle
# ...                                                  ...
# 11356            https://www.linkedin.com/company/byredo
# 11357         https://www.linkedin.com/company/pros2plan
# 11358  https://www.linkedin.com/company/ascendoresources
# 11359    https://www.linkedin.com/company/the-crox-group
# 11360     https://www.linkedin.com/company/sidley-austin
#
# [11361 rows x 10 columns]

# %%
#left join df with company info on company_id
result_df = pd.merge(df, df2, on='company_id', how='left')

#replace the -1s with NaN in company_id
result_df['company_id'] = result_df['company_id'].replace(-1, np.nan)

#show the new df
result_df['original_listed_time']
# Out:
# 0       2023-11-04 09:26:40
# 1       2023-11-04 06:40:00
# 2       2023-11-04 06:40:00
# 3       2023-11-04 06:40:00
# 4       2023-11-03 00:06:40
#                 ...
# 33241   2023-08-23 22:33:20
# 33242   2023-11-03 19:33:20
# 33243   2023-11-03 22:20:00
# 33244   2023-08-23 00:20:00
# 33245   2023-11-03 22:20:00
# Name: original_listed_time, Length: 33246, dtype: datetime64[ns]

# %%
result_df['month_year'] = result_df['original_listed_time'].dt.to_period('M')
monthly_counts = result_df['month_year'].value_counts().sort_index()
monthly_counts_df = pd.DataFrame({'month_year': monthly_counts.index, 'count': monthly_counts.values})
monthly_counts_df = monthly_counts_df.sort_values(by='month_year')
plt.figure(figsize=(10, 6))
plt.plot(monthly_counts_df['month_year'].dt.to_timestamp(), monthly_counts_df['count'], marker='o', linestyle='-')
plt.title('Job Postings per Month')
plt.xlabel('Month and Year')
plt.ylabel('Job Postings')
plt.xticks(rotation=45)
plt.show()

# %%
#This cell looks at record count for job titles and attempts to clean

result_df['Title_Count'] = result_df.groupby('title')['title'].transform('count')

title_result_df_sorted = result_df.sort_values(by='Title_Count', ascending=False)

# Filter rows for City Lifestyle postings
filtered_result_df = title_result_df_sorted[title_result_df_sorted['url'] != 'https://www.linkedin.com/company/citylifestyle']

# Display the filtered DataFrame
print(filtered_result_df)
# Out:
#            job_id  company_id  \
# 31390  3693049649     6591488
# 20609  3700550327    73013724
# 179    3757919585    73013724
# 16239  3749347137      444704
# 158    3757921570    73013724
# ...           ...         ...
# 13698  3754508188       53193
# 13697  3754508213        5471
# 13695  3754508225     1258341
# 13694  3754508252        5107
# 33245     3958427      630152
#
#                                                    title  \
# 31390                                      Sales Manager
# 20609                                      Sales Manager
# 179                                        Sales Manager
# 16239                                      Sales Manager
# 158                                        Sales Manager
# ...                                                  ...
# 13698                      Inventory Control Team Leader
# 13697  Reliability Maintenance Engineering Internship...
# 13695  Fusion Global Academy Virtual Teacher/Mentor -...
# 13694                                Software Engineer 4
# 33245                                   Stylist/ Clorist
#
#                                            description_x  max_salary  \
# 31390  About Teledyne Marine Interconnect Solutions (...         NaN
# 20609  Position Summary: Our Sales Manager has managi...    175000.0
# 179    Position Summary: Our Sales Manager has managi...    350000.0
# 16239  **You must be located in Michigan to be consid...    150000.0
# 158    Position Summary: Our Sales Manager has managi...    350000.0
# ...                                                  ...         ...
# 13698  Creating A Healthier Way of Living\n\nRinnai A...         NaN
# 13697  E. & J. Gallo Winery Privacy Policy\n\nWhy Gal...        27.0
# 13695  Description\n\nFusion Global Academy has openi...         NaN
# 13694  Success Starts Here\n\nAs a leading global sup...    233000.0
# 33245  Karen Marie is looking for an awesome experien...     80000.0
#
#        med_salary  min_salary pay_period formatted_work_type         location  \
# 31390         NaN         NaN        NaN           Full-time       Dallas, TX
# 20609         NaN    125000.0     YEARLY           Full-time  Idaho Falls, ID
# 179           NaN    125000.0     YEARLY           Full-time       Ithaca, NY
# 16239         NaN     75000.0     YEARLY           Full-time      Livonia, MI
# 158           NaN    125000.0     YEARLY           Full-time    Knoxville, TN
# ...           ...         ...        ...                 ...              ...
# 13698       24.04         NaN     HOURLY           Full-time       Hudson, NY
# 13697         NaN        24.0     HOURLY           Full-time    Fort Lawn, SC
# 13695         NaN         NaN        NaN           Full-time    United States
# 13694         NaN    105000.0     YEARLY           Full-time      Fremont, CA
# 33245         NaN     35000.0     YEARLY           Full-time      Chicago, IL
#
#        ...                        name  \
# 31390  ...             Teledyne Marine
# 20609  ...                     J. Galt
# 179    ...                     J. Galt
# 16239  ...        MKD Kitchen and Bath
# 158    ...                     J. Galt
# ...    ...                         ...
# 13698  ...  Rinnai America Corporation
# 13697  ...        E. & J. Gallo Winery
# 13695  ...              Fusion Academy
# 13694  ...                Lam Research
# 33245  ...           Karen Marie Salon
#
#                                            description_y  company_size  \
# 31390  Welcome to the official LinkedIn company page ...           5.0
# 20609  Our mission is to help entrepreneurs obtain th...           3.0
# 179    Our mission is to help entrepreneurs obtain th...           3.0
# 16239  MKD Kitchen and Bath offers full service remod...           2.0
# 158    Our mission is to help entrepreneurs obtain th...           3.0
# ...                                                  ...           ...
# 13698  Rinnai America Corporation, a subsidiary of Ri...           3.0
# 13697  We're the world's largest family-owned wine an...           6.0
# 13695  Over 20 years ago Fusion Academy started as a ...           5.0
# 13694  Lam Research Corp. (NASDAQ:LRCX) is a global s...           7.0
# 33245  Hair salon & in Bucktown! Specializing in colo...           NaN
#
#             state country            city zip_code                  address  \
# 31390     Florida      US   Daytona Beach    32114   1026 N Williamson Blvd
# 20609     Indiana      US    Indianapolis    46268         3500 Depauw Blvd
# 179       Indiana      US    Indianapolis    46268         3500 Depauw Blvd
# 16239           0      US               0    49068                        0
# 158       Indiana      US    Indianapolis    46268         3500 Depauw Blvd
# ...           ...     ...             ...      ...                      ...
# 13698          GA      US  Peachtree City    30269  103 International Drive
# 13697  California      US         Modesto    95354                        0
# 13695          MI      US    Grand Rapids    49503      72 Monroe Center NW
# 13694          CA      US         Fremont    94538     4650 Cushing Parkway
# 33245    Illinois      US         Chicago    60647     1859 N Milwaukee Ave
#
#                                                      url Title_Count
# 31390   https://www.linkedin.com/company/teledyne-marine          99
# 20609  https://www.linkedin.com/company/j-galt-financ...          99
# 179    https://www.linkedin.com/company/j-galt-financ...          99
# 16239  https://www.linkedin.com/company/mkdkitchenand...          99
# 158    https://www.linkedin.com/company/j-galt-financ...          99
# ...                                                  ...         ...
# 13698            https://www.linkedin.com/company/rinnai           1
# 13697  https://www.linkedin.com/company/e-&-j-gallo-w...           1
# 13695    https://www.linkedin.com/company/fusion-academy           1
# 13694      https://www.linkedin.com/company/lam-research           1
# 33245  https://www.linkedin.com/company/karen-marie-s...           1
#
# [33048 rows x 38 columns]

# %%
df['title'].value_counts()
# Out:
# Sales Director [Owner/Operator]                    120
# Sales Manager                                       99
# Project Manager                                     97
# Customer Service Representative                     85
# Senior Accountant                                   83
#                                                   ...
# Client Business Executive - SLED                     1
# Individual Giving Officer                            1
# 1 pm to 5 pm Cashier                                 1
# Sales Representative, Ambulatory Surgery Center      1
# Stylist/ Clorist                                     1
# Name: title, Length: 22404, dtype: int64

# %%
#Plot a bar plot of the top 10 job titles posted on LinkedIn
fig = result_df.groupby('title')['title'].count().sort_values(ascending=False).head(10).plot.bar()
plt.xlabel('Job Title')
plt.ylabel('Number of posts')
plt.title("Most in-demand jobs posted on LinkedIn")
# Out:
# Text(0.5, 1.0, 'Most in-demand jobs posted on LinkedIn')

# %%
#this cell groups by location and returns the mean salary for each location

average_values = df.groupby('location')['med_salary'].mean().reset_index()

result_df = df.groupby('location')['med_salary'].agg(['mean', 'count']).reset_index()

result_df.columns = ['Location', 'Mean', 'Salary Count']

# %%
#this cell sorts by the avg med salary and adds a column that keeps track of how many jobs offer that avg salary

average_values_sorted = average_values.sort_values(by='med_salary', ascending=False)

result_df_sorted = result_df.sort_values(by='Mean', ascending=False)

# Assuming result_df_sorted is the DataFrame you want to modify
result_df_filtered = result_df_sorted.loc[result_df_sorted['Salary Count'] > 1]

# Display the sorted result
print(average_values_sorted)

# Display the modified DataFrame
print(result_df_filtered)

# %%
# Plot a scatter plot of the locations with the 10 highest mean salary
result_df_filtered.head(10).plot.scatter(x='Location', y='Mean')
plt.xticks(rotation=90)
plt.xlabel("Job Location")
plt.ylabel("Mean Salary")
plt.title("Location of top mean salaries posted on LinkedIn")

# %%
result_df.columns
